# %% [markdown]
# Citing <cite data-cite="batpol"></cite> and <cite data-cite="29383/QTCKJCDM"></cite> and <cite data-cite="29383/29XGSBTZ"></cite>
#
# Also, an interesting paper is <cite data-cite="allium_vavilovii"/> blash

# %% [markdown]
# <cite data-cite="29383/R7MVWURF"></cite>

# %% [markdown]
# ## Bibliography
#
# <div class="cite2c-biblio"></div>
